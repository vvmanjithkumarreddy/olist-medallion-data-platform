-- %% [markdown]
-- # Create Operations View

-- %%
CREATE OR REPLACE VIEW olist_catalog.gold.vw_operations
AS
SELECT
    o.order_id,
    o.order_status,
    o.delivery_days,
    o.estimated_delivery_days,
    o.delivery_status
from olist_catalog.gold.fact_orders o
