-- %% [markdown]
-- # Setup Project Environment for the Olist-medallion-data-platform project
--
-- 1. Created Schemas landing, bronze, silver and gold
-- 2. Create Volume files in the landing Schema

-- %%
SHOW CATALOGS;

-- %%
USE CATALOG olist_catalog;

-- %% [markdown]
-- ## Creating Schemas landing, bronze, silver and gold

-- %%
CREATE SCHEMA IF NOT EXISTS landing;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

-- %%
SHOW SCHEMAS;

-- %% [markdown]
-- ## Creating Volume in landing

-- %%
CREATE VOLUME landing.files;
